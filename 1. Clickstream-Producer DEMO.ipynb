# %%
# import statements
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random
import datetime as dt
import csv

#configuration
hostip = "192.168.100.4" #change me

topic = 'clickstream'


def readCSVFile(fileName):
    list=[]
    with open('clickstream.csv', 'rt') as f:
        reader = csv.DictReader(f)
        for row in reader:
            list.append({'Clicks':int(row['Clicks']),'Impressions':int(row['Impressions'])})
    return list

def publish_message(producer_instance, topic_name, data):
    try:
        producer_instance.send(topic_name, data)
        #print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    cRows = readCSVFile('clickstream.csv')
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    #sending single object
    rows_to_send=1
    start_index=0
    while True:        
        to_send = cRows[start_index]        
        #increase the start index by the number of rows taken
        start_index = start_index+rows_to_send
        
        #define the current timestamp
        ts = {'ts': int(dt.datetime.now().timestamp())}
        
        #append the timestamp into the object to be sent
        data=dict(to_send,**ts)
        print(data)
        
        publish_message(producer, topic, data)
        
        #reset to start from begining
        if(start_index>=len(cRows)):
            start_index=0
        sleep(1)
# Out:
# Publishing records..
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680663961}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680663962}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680663963}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680663964}
# {'Clicks': 0, 'Impressions': 11, 'ts': 1680663965}
# {'Clicks': 1, 'Impressions': 11, 'ts': 1680663966}
# {'Clicks': 1, 'Impressions': 7, 'ts': 1680663967}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680663968}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680663969}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680663970}
# {'Clicks': 1, 'Impressions': 8, 'ts': 1680663971}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680663972}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680663973}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680663974}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680663975}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680663976}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680663977}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680663978}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680663979}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680663980}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680663981}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680663982}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680663983}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680663984}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680663985}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680663986}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680663987}
# {'Clicks': 0, 'Impressions': 9, 'ts': 1680663988}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680663989}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680663990}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680663991}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680663992}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680663994}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680663995}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680663996}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680663997}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680663998}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680663999}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664000}
# {'Clicks': 2, 'Impressions': 7, 'ts': 1680664001}
# {'Clicks': 0, 'Impressions': 9, 'ts': 1680664002}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664003}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664004}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664005}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664006}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664007}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664008}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664009}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664010}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664011}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664012}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664013}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664014}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664015}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664016}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664017}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664018}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664019}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664020}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664021}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664022}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664023}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664024}
# {'Clicks': 1, 'Impressions': 2, 'ts': 1680664025}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664026}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664027}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664028}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664029}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664030}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664031}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664032}
# {'Clicks': 0, 'Impressions': 10, 'ts': 1680664033}
# {'Clicks': 1, 'Impressions': 6, 'ts': 1680664034}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664035}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664036}
# {'Clicks': 1, 'Impressions': 7, 'ts': 1680664037}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664038}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664039}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664040}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664041}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664042}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664043}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664044}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664045}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664046}
# {'Clicks': 1, 'Impressions': 7, 'ts': 1680664047}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664048}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664049}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664050}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664051}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664052}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664053}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664054}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664055}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664056}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664057}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664058}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664059}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664060}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664061}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664062}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664063}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664064}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664065}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664066}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664067}
# {'Clicks': 1, 'Impressions': 2, 'ts': 1680664068}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664069}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664070}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664071}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664072}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664073}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664074}
# {'Clicks': 0, 'Impressions': 9, 'ts': 1680664075}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664076}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664077}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664078}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664079}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664080}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664081}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664082}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664083}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664084}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664085}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664086}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664087}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664088}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664089}
# {'Clicks': 1, 'Impressions': 3, 'ts': 1680664090}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664091}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664092}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664093}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664094}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664095}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664096}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664097}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664098}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664099}
# {'Clicks': 0, 'Impressions': 9, 'ts': 1680664100}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664101}
# {'Clicks': 0, 'Impressions': 11, 'ts': 1680664102}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664103}
# {'Clicks': 1, 'Impressions': 7, 'ts': 1680664104}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664105}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664106}
# {'Clicks': 1, 'Impressions': 6, 'ts': 1680664107}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664108}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664109}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664110}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664111}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664112}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664113}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664114}
# {'Clicks': 1, 'Impressions': 4, 'ts': 1680664115}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664116}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664117}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664118}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664119}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664120}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664121}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664122}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664123}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664124}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664125}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664126}
# {'Clicks': 0, 'Impressions': 9, 'ts': 1680664127}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664128}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664129}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664130}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664131}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664132}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664133}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664134}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664135}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664137}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664138}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664139}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664140}
# {'Clicks': 1, 'Impressions': 7, 'ts': 1680664141}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664142}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664143}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664144}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664145}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664146}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664147}
# {'Clicks': 0, 'Impressions': 10, 'ts': 1680664148}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664149}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664150}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664151}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664152}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664154}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664155}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664156}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664157}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664158}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664159}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664160}
# {'Clicks': 2, 'Impressions': 7, 'ts': 1680664161}
# {'Clicks': 1, 'Impressions': 5, 'ts': 1680664162}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664163}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664164}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664165}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664167}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664168}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664169}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664170}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664171}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664172}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664173}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664174}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664175}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664176}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664177}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664178}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664179}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664180}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664181}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664182}
# {'Clicks': 1, 'Impressions': 5, 'ts': 1680664184}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664185}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664186}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664187}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664188}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664189}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664190}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664191}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664192}
# {'Clicks': 0, 'Impressions': 11, 'ts': 1680664193}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664194}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664195}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664196}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664197}
# {'Clicks': 0, 'Impressions': 10, 'ts': 1680664198}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664199}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664200}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664201}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664202}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664203}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664204}
# {'Clicks': 1, 'Impressions': 9, 'ts': 1680664205}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664206}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664207}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664209}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664210}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664211}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664212}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664213}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664214}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664215}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664216}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664217}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664218}
# {'Clicks': 1, 'Impressions': 6, 'ts': 1680664219}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664220}
# {'Clicks': 1, 'Impressions': 7, 'ts': 1680664221}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664222}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664223}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664224}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664225}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664226}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664227}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664228}
# {'Clicks': 0, 'Impressions': 10, 'ts': 1680664229}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664230}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664233}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664234}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664235}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664236}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664237}
# {'Clicks': 1, 'Impressions': 5, 'ts': 1680664238}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664240}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664241}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664242}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664243}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664244}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664245}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664246}
# {'Clicks': 1, 'Impressions': 9, 'ts': 1680664247}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664248}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664249}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664250}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664251}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664252}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664253}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664254}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664255}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664256}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664257}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664258}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664259}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664269}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664270}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664271}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664272}
# {'Clicks': 1, 'Impressions': 5, 'ts': 1680664273}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664275}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664276}
# {'Clicks': 1, 'Impressions': 4, 'ts': 1680664278}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664279}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664280}
# {'Clicks': 0, 'Impressions': 0, 'ts': 1680664281}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664282}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664283}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664284}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664285}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664286}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664287}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664288}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664289}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664290}
# {'Clicks': 0, 'Impressions': 0, 'ts': 1680664291}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664292}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664293}
# {'Clicks': 1, 'Impressions': 4, 'ts': 1680664294}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664295}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664296}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664297}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664298}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664299}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664300}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664301}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664302}
# {'Clicks': 0, 'Impressions': 10, 'ts': 1680664303}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664304}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664305}
# {'Clicks': 0, 'Impressions': 9, 'ts': 1680664306}
# {'Clicks': 0, 'Impressions': 9, 'ts': 1680664307}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664308}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664309}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664310}
# {'Clicks': 0, 'Impressions': 10, 'ts': 1680664311}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664312}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664313}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664314}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664315}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664316}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664317}
# {'Clicks': 1, 'Impressions': 4, 'ts': 1680664318}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664319}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664320}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664321}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664322}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664323}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664324}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664325}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664326}
# {'Clicks': 0, 'Impressions': 1, 'ts': 1680664327}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664328}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664329}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664330}
# {'Clicks': 1, 'Impressions': 8, 'ts': 1680664331}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664332}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664333}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664334}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664335}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664336}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664337}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664338}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664339}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664340}
# {'Clicks': 0, 'Impressions': 5, 'ts': 1680664342}
# {'Clicks': 0, 'Impressions': 9, 'ts': 1680664343}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664344}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664345}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664346}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664347}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664348}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664349}
# {'Clicks': 1, 'Impressions': 6, 'ts': 1680664350}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664351}
# {'Clicks': 0, 'Impressions': 9, 'ts': 1680664352}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664353}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664354}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664355}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664356}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664357}
# {'Clicks': 1, 'Impressions': 6, 'ts': 1680664358}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664359}
# {'Clicks': 1, 'Impressions': 5, 'ts': 1680664360}
# {'Clicks': 0, 'Impressions': 8, 'ts': 1680664363}
# {'Clicks': 0, 'Impressions': 2, 'ts': 1680664364}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664365}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664366}
# {'Clicks': 0, 'Impressions': 9, 'ts': 1680664367}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664368}
# {'Clicks': 0, 'Impressions': 7, 'ts': 1680664373}
# {'Clicks': 0, 'Impressions': 6, 'ts': 1680664374}
# {'Clicks': 0, 'Impressions': 3, 'ts': 1680664375}
# {'Clicks': 0, 'Impressions': 4, 'ts': 1680664376}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 70
#      68 if(start_index>=len(cRows)):
#      69     start_index=0
# ---> 70 sleep(1)
#
# KeyboardInterrupt:
